# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/2_Advanced/03_Pandas_Data_Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Data Management

# %% [markdown]
# Load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ## Copy

# %% [markdown]
# Recall from the last lesson, when we filled in missing values for median salary.
#
# Here let's make a new dataframe `df_altered` and only make changes to it.

# %%
# Create new dataframe
df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Let's fill in missing values with the median value.

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %% [markdown]
# Now let's inspect the altered DataFrame.

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# That was good...
#
# But what about the original...

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Holdup!! How the heck did `df_original` get altered!?!

# %% [markdown]
# Well both the variables of `df_original` and `df_altered` are referencing the same DataFrame.

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                6275519568
# ID of df_altered:                 6275519568
# Are the two dataframes the same?  True

# %% [markdown]
# Instead we can use the .copy() method
#
# - `copy()`: Copy a DataFrame.

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                4402364816
# ID of df_altered:                 6276875840
# Are the two dataframes the same?  False

# %% [markdown]
# Now when we do this same operation:

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# The original dataframe doesn't get altered!

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Now that we've created a copy of our data, we want to start our analysis. But if we have a large set of data we only want to take a subset of data to make it more manageable. We can use `sample()` to get a random sample of the data.

# %% [markdown]
# ## Sample
#
# ### Notes
#
# * `sample()`: Random sample of items.
#
# ### Examples
#
# Let's get a random sample of the data. You could get a sample with a fixed row number.

# %%
df.sample(n=5)
# Out:
#               job_title_short                                 job_title  \
# 94079          Data Scientist  Graduate Data Scientist - 2023 Programme
# 662109  Senior Data Scientist      Data Scientist or Sr. Data Scientist
# 591139         Data Scientist                        Sr. Data Scientist
# 342798          Data Engineer    Finnish Speaking - Azure Data Engineer
# 311384    Senior Data Analyst     Senior Data analyst customer insights
#
#                job_location        job_via job_schedule_type  \
# 94079         Llandudno, UK   via Fonoplus         Full-time
# 662109         Amarillo, TX    via Ladders         Full-time
# 591139  Taipei City, Taiwan  via Indeed 台灣               NaN
# 342798     Tampere, Finland   via Mendeley        Contractor
# 311384             Anywhere     via Indeed         Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 94079                False        United Kingdom 2023-01-25 00:16:54
# 662109               False  Texas, United States 2023-02-18 10:03:37
# 591139               False                Taiwan 2023-12-19 09:45:25
# 342798               False               Finland 2023-06-08 23:42:15
# 311384                True           Netherlands 2023-07-13 17:16:19
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 94079                   False                 False  United Kingdom
# 662109                  False                  True   United States
# 591139                  False                 False          Taiwan
# 342798                   True                 False         Finland
# 311384                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg company_name  \
# 94079          NaN              NaN              NaN          CGG
# 662109        year         115000.0              NaN  Xcel Energy
# 591139         NaN              NaN              NaN       1111獵頭
# 342798         NaN              NaN              NaN   Technojobs
# 311384         NaN              NaN              NaN       Action
#
#                                                job_skills  \
# 94079   ['python', 'sql', 'java', 'neo4j', 'spring', '...
# 662109                       ['sql', 'python', 'express']
# 591139  ['java', 'c++', 'python', 'aws', 'azure', 'ten...
# 342798  ['sql', 'python', 'powershell', 'azure', 'data...
# 311384  ['go', 'sql', 'python', 'databricks', 'azure',...
#
#                                           job_type_skills
# 94079   {'databases': ['neo4j'], 'libraries': ['spring...
# 662109  {'programming': ['sql', 'python'], 'webframewo...
# 591139  {'cloud': ['aws', 'azure'], 'libraries': ['ten...
# 342798  {'cloud': ['azure', 'databricks'], 'other': ['...
# 311384  {'analyst_tools': ['looker'], 'cloud': ['datab...

# %% [markdown]
# Or you can randomly select a fraction of the data (e.g., 10% of the rows), with or without replacement.

# %%
df.sample(frac=0.1, replace=False)
# Out:
#                   job_title_short  \
# 155102  Machine Learning Engineer
# 503298             Data Scientist
# 380064              Data Engineer
# 69073                Data Analyst
# 506103             Data Scientist
# ...                           ...
# 254929             Cloud Engineer
# 333971              Data Engineer
# 612640       Senior Data Engineer
# 498416       Senior Data Engineer
# 660927               Data Analyst
#
#                                                 job_title  \
# 155102         Data Scientist / Machine Learning Engineer
# 503298  Alternant en Data Scientist et Innovation digi...
# 380064                                Data Engineer - H/F
# 69073                                 Junior Data Analyst
# 506103                                Data Scientist, Mid
# ...                                                   ...
# 254929                  Senior Electrical Design Engineer
# 333971                    Data Engineer - mobiles möglich
# 612640       Senior Data Architect, Professional Services
# 498416      Senior Data Engineer, Marketing Effectiveness
# 660927        Data Analyst im Bereich Controlling (m/w/d)
#
#                  job_location            job_via job_schedule_type  \
# 155102                 France       via LinkedIn         Full-time
# 503298      Montreuil, France       via LinkedIn         Part-time
# 380064       Bordeaux, France         via Indeed         Full-time
# 69073          Kraków, Poland    via Trabajo.org         Full-time
# 506103          Arlington, TX    via Trabajo.org         Full-time
# ...                       ...                ...               ...
# 254929        Dublin, Ireland  via BeBee Ireland         Full-time
# 333971     Nuremberg, Germany     via Learn4Good         Full-time
# 612640          United States       via LinkedIn         Full-time
# 498416             London, UK      via WJHL Jobs         Full-time
# 660927  Germany   (+2 others)      via Stepstone         Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 155102               False                France 2023-11-13 08:55:22
# 503298               False                France 2023-06-06 11:21:49
# 380064               False                France 2023-05-29 18:17:12
# 69073                False                Poland 2023-04-18 06:45:46
# 506103               False  Texas, United States 2023-02-08 19:03:45
# ...                    ...                   ...                 ...
# 254929               False               Ireland 2023-05-28 07:43:21
# 333971               False               Germany 2023-09-09 00:18:29
# 612640               False  Texas, United States 2023-11-12 12:05:27
# 498416               False        United Kingdom 2023-07-02 11:35:50
# 660927               False               Germany 2023-12-15 10:16:10
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 155102                  False                 False          France
# 503298                  False                 False          France
# 380064                   True                 False          France
# 69073                   False                 False          Poland
# 506103                  False                  True   United States
# ...                       ...                   ...             ...
# 254929                  False                 False         Ireland
# 333971                   True                 False         Germany
# 612640                  False                  True   United States
# 498416                   True                 False  United Kingdom
# 660927                   True                 False         Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 155102         NaN              NaN              NaN
# 503298         NaN              NaN              NaN
# 380064         NaN              NaN              NaN
# 69073          NaN              NaN              NaN
# 506103         NaN              NaN              NaN
# ...            ...              ...              ...
# 254929         NaN              NaN              NaN
# 333971         NaN              NaN              NaN
# 612640         NaN              NaN              NaN
# 498416         NaN              NaN              NaN
# 660927         NaN              NaN              NaN
#
#                                        company_name  \
# 155102  Free-Work (ex Freelance-info Carriere-info)
# 503298                                  BNP Paribas
# 380064                                        Seyos
# 69073                                    KION Group
# 506103                          Booz Allen Hamilton
# ...                                             ...
# 254929                      Core Talent Recruitment
# 333971                      NÜRNBERGER Versicherung
# 612640                    Amazon Web Services (AWS)
# 498416                                  Jobleads-UK
# 660927                             arano group GmbH
#
#                                                job_skills  \
# 155102          ['scikit-learn', 'tensorflow', 'pytorch']
# 503298                    ['excel', 'word', 'powerpoint']
# 380064  ['scala', 'sql', 'kotlin', 'snowflake', 'azure...
# 69073                 ['sap', 'power bi', 'dax', 'excel']
# 506103  ['python', 'c++', 'java', 'r', 'scala', 'elast...
# ...                                                   ...
# 254929                                                NaN
# 333971  ['c#', 'sas', 'sas', 'java', 'oracle', 'spring...
# 612640  ['sql', 'nosql', 'aws', 'hadoop', 'spark', 'ka...
# 498416  ['sql', 'nosql', 'python', 'scala', 'aws', 'sp...
# 660927                ['power bi', 'excel', 'powerpoint']
#
#                                           job_type_skills
# 155102  {'libraries': ['scikit-learn', 'tensorflow', '...
# 503298  {'analyst_tools': ['excel', 'word', 'powerpoin...
# 380064  {'cloud': ['snowflake', 'azure'], 'libraries':...
# 69073   {'analyst_tools': ['sap', 'power bi', 'dax', '...
# 506103  {'analyst_tools': ['tableau', 'qlik'], 'cloud'...
# ...                                                   ...
# 254929                                                NaN
# 333971  {'analyst_tools': ['sas'], 'cloud': ['oracle']...
# 612640  {'cloud': ['aws'], 'libraries': ['hadoop', 'sp...
# 498416  {'cloud': ['aws'], 'libraries': ['spark', 'air...
# 660927  {'analyst_tools': ['power bi', 'excel', 'power...
#
# [78574 rows x 17 columns]

# %% [markdown]
# Now you can analyze these subsets of data.
